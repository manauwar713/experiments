# %%
import numpy as np

# %%
import pandas as pd
data = pd.read_csv('/raid/syscon/malam/experiments/data/raw/adult.csv')
data.head()
data.shape
# Out:
# (48842, 15)

# %%
data['workclass']=data['workclass'].replace('?',np.nan)
data['occupation']=data['occupation'].replace('?',np.nan)
data['native-country']=data['native-country'].replace('?',np.nan)

# %%
df = data.copy()
df.dropna(how='any',inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
df.shape
# Out:
# (45222, 15)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (45175, 15)

# %%
df = df.drop(['education', 'capital-gain', 'capital-loss'], axis=1)

# %%
df.shape
# Out:
# (45175, 12)

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  educational-num      marital-status  \
# 0   25    Private  226802                7       Never-married
# 1   38    Private   89814                9  Married-civ-spouse
# 2   28  Local-gov  336951               12  Married-civ-spouse
# 3   44    Private  160323               10  Married-civ-spouse
# 5   34    Private  198693                6       Never-married
#
#           occupation   relationship   race gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black   Male              40
# 1    Farming-fishing        Husband  White   Male              50
# 2    Protective-serv        Husband  White   Male              40
# 3  Machine-op-inspct        Husband  Black   Male              40
# 5      Other-service  Not-in-family  White   Male              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# 3  United-States   >50K
# 5  United-States  <=50K

# %%
df.to_csv('/raid/syscon/malam/experiments/data/raw/cleaned_adult.csv', index=False)

# %%
new_df = pd.read_csv("/raid/syscon/malam/experiments/data/raw/cleaned_adult.csv")

# %%
new_df.shape
# Out:
# (45175, 12)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
new_df['gender'] = label_encoder.fit_transform(new_df['gender'])

# %%
new_df.head()
# Out:
#    age  workclass  fnlwgt  educational-num      marital-status  \
# 0   25    Private  226802                7       Never-married
# 1   38    Private   89814                9  Married-civ-spouse
# 2   28  Local-gov  336951               12  Married-civ-spouse
# 3   44    Private  160323               10  Married-civ-spouse
# 4   34    Private  198693                6       Never-married
#
#           occupation   relationship   race  gender  hours-per-week  \
# 0  Machine-op-inspct      Own-child  Black       1              40
# 1    Farming-fishing        Husband  White       1              50
# 2    Protective-serv        Husband  White       1              40
# 3  Machine-op-inspct        Husband  Black       1              40
# 4      Other-service  Not-in-family  White       1              30
#
#   native-country income
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States   >50K
# 3  United-States   >50K
# 4  United-States  <=50K

# %%
import os
for file in os.listdir('/raid/syscon/malam/experiments/data/interim'):
    if file == '.gitkeep':
        continue
    else:
        df = pd.read_csv(os.path.join('/raid/syscon/malam/experiments/data/interim',file))
        gender_counts = df['gender'].value_counts()
        total_samples = gender_counts.sum()
        if len(gender_counts) == 1:
            continue
        else:
            male_proportion = gender_counts[1] / total_samples
            female_proportion = gender_counts[0] / total_samples
            
            
            print(f'Proportion of Male- {male_proportion},proportion of female-{female_proportion}')
# Out:
# Proportion of Male- 0.21339606974813174,proportion of female-0.7866039302518683
# Proportion of Male- 0.7246055909216718,proportion of female-0.27539440907832824
# Proportion of Male- 0.9914198726819817,proportion of female-0.008580127318018268
# Proportion of Male- 0.9083863825076114,proportion of female-0.0916136174923886
# Proportion of Male- 0.773318571823969,proportion of female-0.22668142817603099
# Proportion of Male- 0.8834763354553004,proportion of female-0.1165236645446997
# Proportion of Male- 0.012178245225574315,proportion of female-0.9878217547744257
# Proportion of Male- 0.6208137282037088,proportion of female-0.37918627179629116
# Proportion of Male- 0.6334529395528568,proportion of female-0.36654706044714325
